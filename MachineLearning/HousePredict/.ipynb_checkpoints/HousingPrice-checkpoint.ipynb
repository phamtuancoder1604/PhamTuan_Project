# %%
import pandas as pd
import numpy as np
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
mc = []
for col in train.columns:
    missing_value = train[col].isna().sum()
    if missing_value > 0 : 
        mc.append(col)
mc
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
x = train.drop(['LotFrontage',
 'Alley',
 'MasVnrType',
 'BsmtQual',
 'BsmtCond',
 'BsmtExposure',
 'BsmtFinType1',
 'BsmtFinType2',
 'FireplaceQu',
 'GarageType',
 'GarageYrBlt',
 'GarageFinish',
 'GarageQual',
 'GarageCond',
 'PoolQC',
 'Fence',
 'MiscFeature', 'Id','SalePrice'],axis = 1)
x
# Out:
#       MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0             60       RL     8450   Pave      Reg         Lvl    AllPub
# 1             20       RL     9600   Pave      Reg         Lvl    AllPub
# 2             60       RL    11250   Pave      IR1         Lvl    AllPub
# 3             70       RL     9550   Pave      IR1         Lvl    AllPub
# 4             60       RL    14260   Pave      IR1         Lvl    AllPub
# ...          ...      ...      ...    ...      ...         ...       ...
# 1455          60       RL     7917   Pave      Reg         Lvl    AllPub
# 1456          20       RL    13175   Pave      Reg         Lvl    AllPub
# 1457          70       RL     9042   Pave      Reg         Lvl    AllPub
# 1458          20       RL     9717   Pave      Reg         Lvl    AllPub
# 1459          20       RL     9937   Pave      Reg         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood  ... OpenPorchSF EnclosedPorch  \
# ...

# %%
test = test.drop(['LotFrontage',
 'Alley',
 'MasVnrType',
 'BsmtQual',
 'BsmtCond',
 'BsmtExposure',
 'BsmtFinType1',
 'BsmtFinType2',
 'FireplaceQu',
 'GarageType',
 'GarageYrBlt',
 'GarageFinish',
 'GarageQual',
 'GarageCond',
 'PoolQC',
 'Fence',
 'MiscFeature', 'Id'],axis = 1)
test
# Out:
#       MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0             20       RH    11622   Pave      Reg         Lvl    AllPub
# 1             20       RL    14267   Pave      IR1         Lvl    AllPub
# 2             60       RL    13830   Pave      IR1         Lvl    AllPub
# 3             60       RL     9978   Pave      IR1         Lvl    AllPub
# 4            120       RL     5005   Pave      IR1         HLS    AllPub
# ...          ...      ...      ...    ...      ...         ...       ...
# 1454         160       RM     1936   Pave      Reg         Lvl    AllPub
# 1455         160       RM     1894   Pave      Reg         Lvl    AllPub
# 1456          20       RL    20000   Pave      Reg         Lvl    AllPub
# 1457          85       RL    10441   Pave      Reg         Lvl    AllPub
# 1458          60       RL     9627   Pave      Reg         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood  ... OpenPorchSF EnclosedPorch  \
# ...

# %%
numericals = x.select_dtypes(include = ['float64','int64']).columns
numericals
# Out:
# Index(['MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
#        'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#        'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars',
#        'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold'],
#       dtype='object')

# %%
categoricals= x.select_dtypes(include = ['object','category']).columns 
categoricals
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional',
#        'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
y = train.iloc[:,-1:]#SalePrice
y1 = train.SalePrice

# %%
import seaborn as sns 
sns.displot(x = y1, kde = True, bins =  10);

# %%
import matplotlib.pyplot as plt 
for col in numericals:
    plt.figure(figsize = (8,4))
    sns.histplot(x = x[col], kde = True, bins = 30)
    plt.title(f'Distribution of {col}')
    plt.show()
    
    sns.boxplot(x= x[col])
    plt.title(f'Box plot of {col}')
    plt.show()

for col in categoricals:
    plt.figure(figsize = (8,4))
    sns.countplot(x = x[col])
    plt.title(f'Countplot of {col}')
    plt.xticks(rotation=45)
    plt.show()

# %%
features = [
    "MasVnrArea",
    "BsmtFinSF1",
    "BsmtFinSF2",
    "BsmtUnfSF",
    "BsmtFullBath",
    "BsmtHalfBath",
    "Fireplaces",
    "WoodDeckSF",
    "OpenPorchSF",
    "EnclosedPorch",
    "3SsnPorch",
    "ScreenPorch",
    "Street",
    "RoofStyle",
    "RoofMatl",
    "Heating",
    "HeatingQC",
]
x = x.drop(features, axis = 1)
x
# Out:
#       MSSubClass MSZoning  LotArea LotShape LandContour Utilities LotConfig  \
# 0             60       RL     8450      Reg         Lvl    AllPub    Inside
# 1             20       RL     9600      Reg         Lvl    AllPub       FR2
# 2             60       RL    11250      IR1         Lvl    AllPub    Inside
# 3             70       RL     9550      IR1         Lvl    AllPub    Corner
# 4             60       RL    14260      IR1         Lvl    AllPub       FR2
# ...          ...      ...      ...      ...         ...       ...       ...
# 1455          60       RL     7917      Reg         Lvl    AllPub    Inside
# 1456          20       RL    13175      Reg         Lvl    AllPub    Inside
# 1457          70       RL     9042      Reg         Lvl    AllPub    Inside
# 1458          20       RL     9717      Reg         Lvl    AllPub    Inside
# 1459          20       RL     9937      Reg         Lvl    AllPub    Inside
#
# ...

# %%
categoricals = ['MSZoning',  'LotShape', 'LandContour', 'Utilities',
       'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
       'BldgType', 'HouseStyle',   'Exterior1st',
       'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation', 
        'CentralAir', 'Electrical', 'KitchenQual', 'Functional',
       'PavedDrive', 'SaleType', 'SaleCondition']

# %%
from sklearn.model_selection import train_test_split 
X_train, X_val, y_train, y_val = train_test_split(x,y,train_size = 0.8,test_size = 0.2, random_state = 0)
X_train.head()
# Out:
#      MSSubClass MSZoning  LotArea LotShape LandContour Utilities LotConfig  \
# 618          20       RL    11694      Reg         Lvl    AllPub    Inside
# 870          20       RL     6600      Reg         Lvl    AllPub    Inside
# 92           30       RL    13360      IR1         HLS    AllPub    Inside
# 817          20       RL    13265      IR1         Lvl    AllPub   CulDSac
# 302          20       RL    13704      IR1         Lvl    AllPub    Corner
#
#     LandSlope Neighborhood Condition1  ... Functional GarageCars GarageArea  \
# 618       Gtl      NridgHt       Norm  ...        Typ          3        774
# 870       Gtl        NAmes       PosN  ...        Typ          1        308
# 92        Gtl      Crawfor       Norm  ...        Typ          2        432
# 817       Gtl      Mitchel       Norm  ...        Typ          3        857
# 302       Gtl      CollgCr       Norm  ...        Typ          3        843
#
# ...

# %%
X_train.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotArea', 'LotShape', 'LandContour',
#        'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#        'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'Exterior1st', 'Exterior2nd', 'ExterQual',
#        'ExterCond', 'Foundation', 'TotalBsmtSF', 'CentralAir', 'Electrical',
#        '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'GarageCars', 'GarageArea', 'PavedDrive',
#        'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
selected_columns = [
    'MSSubClass', 'MSZoning', 'LotArea', 'LotShape', 'LandContour',
    'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
    'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond',
    'YearBuilt', 'YearRemodAdd', 'Exterior1st', 'Exterior2nd', 'ExterQual',
    'ExterCond', 'Foundation', 'TotalBsmtSF', 'CentralAir', 'Electrical',
    '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'FullBath',
    'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
    'TotRmsAbvGrd', 'Functional', 'GarageCars', 'GarageArea', 'PavedDrive',
    'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SaleType', 'SaleCondition'
]

# Select only the specified columns
test = test[selected_columns]
test
# Out:
#       MSSubClass MSZoning  LotArea LotShape LandContour Utilities LotConfig  \
# 0             20       RH    11622      Reg         Lvl    AllPub    Inside
# 1             20       RL    14267      IR1         Lvl    AllPub    Corner
# 2             60       RL    13830      IR1         Lvl    AllPub    Inside
# 3             60       RL     9978      IR1         Lvl    AllPub    Inside
# 4            120       RL     5005      IR1         HLS    AllPub    Inside
# ...          ...      ...      ...      ...         ...       ...       ...
# 1454         160       RM     1936      Reg         Lvl    AllPub    Inside
# 1455         160       RM     1894      Reg         Lvl    AllPub    Inside
# 1456          20       RL    20000      Reg         Lvl    AllPub    Inside
# 1457          85       RL    10441      Reg         Lvl    AllPub    Inside
# 1458          60       RL     9627      Reg         Lvl    AllPub    Inside
#
# ...

# %%
from sklearn.impute import SimpleImputer 
from sklearn.preprocessing import OneHotEncoder , LabelEncoder, OrdinalEncoder
from sklearn.compose import ColumnTransformer 
from sklearn.pipeline import Pipeline 
# numerical_cols = SimpleImputer(strategy = 'mean')
# categorical_cols = Pipeline(steps = [('imputer',SimpleImputer(strategy = 'most_frequent')),
#                                      ('onehot',OneHotEncoder(handle_unknown = 'ignore'))])
# preprocessor = ColumnTransformer(transformers = [('num',numerical_cols,numericals ),
#                                                 ('cat',categorical_cols, categoricals)])

# %%
if isinstance(y_train, pd.DataFrame):
    print("df is a DataFrame")
else:
    print("df is NOT a DataFrame")
# Out:
# df is a DataFrame

# %%
od = OrdinalEncoder()
X_train[categoricals] = od.fit_transform(X_train[categoricals])
X_val[categoricals] = od.fit_transform(X_val[categoricals])

# %%
X_train.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotArea', 'LotShape', 'LandContour',
#        'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#        'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'Exterior1st', 'Exterior2nd', 'ExterQual',
#        'ExterCond', 'Foundation', 'TotalBsmtSF', 'CentralAir', 'Electrical',
#        '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'GarageCars', 'GarageArea', 'PavedDrive',
#        'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
test[categoricals] = od.fit_transform(test[categoricals])
test
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_5488\2614374125.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[categoricals] = od.fit_transform(test[categoricals])
#       MSSubClass  MSZoning  LotArea  LotShape  LandContour  Utilities  \
# 0             20       2.0    11622       3.0          3.0        0.0
# 1             20       3.0    14267       0.0          3.0        0.0
# 2             60       3.0    13830       0.0          3.0        0.0
# 3             60       3.0     9978       0.0          3.0        0.0
# 4            120       3.0     5005       0.0          1.0        0.0
# ...          ...       ...      ...       ...          ...        ...
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators = 100 , random_state = 0)
# pipeline = Pipeline(steps = [('preprocessor',preprocessor),
#                             ('model',model)])
model.fit(X_train,y_train)
predict = model.predict(X_val)
predict
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# array([212844.5       , 140627.62      , 104377.66      , 228858.45      ,
#         91805.        , 104515.6       , 249529.55      , 116395.16      ,
#        601233.07      , 153286.22      , 195225.03      , 158503.        ,
#        224076.67      , 106641.76      , 128312.75      , 143404.5       ,
#        221904.74      , 112294.75      , 154804.49      , 174927.05      ,
#        118734.9       , 143814.5       , 113431.39      , 166413.11      ,
#        181504.75      , 218860.98      , 171299.32      ,  87286.66      ,
#        340557.98      , 111923.12      , 143353.12      , 197492.19      ,
#        140321.85      , 295939.8       , 347843.62      , 181377.16      ,
# ...

# %%
# array_data = np.array([
#     212844.5, 140627.62, 104377.66, 228858.45, 91805., 104515.6, 249529.55, 116395.16,
#     601233.07, 153286.22, 195225.03, 158503., 224076.67, 106641.76, 128312.75, 143404.5,
#     221904.74, 112294.75, 154804.49, 174927.05, 118734.9, 143814.5, 113431.39, 166413.11,
#     181504.75, 218860.98, 171299.32, 87286.66, 340557.98, 111923.12, 143353.12, 197492.19,
#     140321.85, 295939.8, 347843.62, 181377.16, 285148.8, 124052.5, 232385.72, 301889.12
# ])

# Create a DataFrame
df = pd.DataFrame(predict, columns=['SalePrice'])
df_combine = pd.concat([df,y_val],axis = 1)
df_combine.head(20)
# Out:
#     SalePrice  SalePrice
# 0   212844.50        NaN
# 1   140627.62   181500.0
# 2   104377.66   223500.0
# 3   228858.45        NaN
# 4    91805.00   250000.0
# 5   104515.60   143000.0
# 6   249529.55        NaN
# 7   116395.16        NaN
# 8   601233.07        NaN
# 9   153286.22   118000.0
# 10  195225.03        NaN
# 11  158503.00        NaN
# 12  224076.67        NaN
# 13  106641.76        NaN
# 14  128312.75   157000.0
# 15  143404.50        NaN
# 16  221904.74        NaN
# 17  112294.75        NaN
# 18  154804.49   159000.0
# 19  174927.05   139000.0

# %%
from sklearn.metrics import mean_absolute_error 
print("Mean Absolute Error: " + str(mean_absolute_error(predict, y_val)))
# Out:
# Mean Absolute Error: 17912.09932648402

# %%
predict_test = model.predict(test)
predict_test
# Out:
# array([124885.24, 156272.5 , 164790.02, ..., 150416.5 , 111426.47,
#        228092.9 ])

# %%
df_test = pd.DataFrame(predict_test, columns=['SalePrice'])
df_combine = pd.concat([df_test,y_val],axis = 1)
df_combine
# Out:
#       SalePrice  SalePrice
# 0     124885.24        NaN
# 1     156272.50   181500.0
# 2     164790.02   223500.0
# 3     179108.00        NaN
# 4     201161.00   250000.0
# ...         ...        ...
# 1454   87810.00        NaN
# 1455   83613.04        NaN
# 1456  150416.50        NaN
# 1457  111426.47        NaN
# 1458  228092.90        NaN
#
# [1459 rows x 2 columns]

# %%
df_test.index.name = 'Id'
df_test
# Out:
#       SalePrice
# Id
# 0     124885.24
# 1     156272.50
# 2     164790.02
# 3     179108.00
# 4     201161.00
# ...         ...
# 1454   87810.00
# 1455   83613.04
# 1456  150416.50
# 1457  111426.47
# 1458  228092.90
#
# [1459 rows x 1 columns]

# %%
df_test.to_csv('HousePricePredict2.csv')

# %%
mae_test = predict_test.mean()
y_val_mae =  y_val.mean()
print("Mean Absolute Error in Test Dataset: " + str(abs(mae_test - y_val_mae)))
# Out:
# Mean Absolute Error in Test Dataset: SalePrice    2457.407976
# dtype: float64

# %%
from xgboost import XGBRegressor
model_2 = XGBRegressor(n_estimators = 10000,random_state = 0, learning_rate = 0.05)
model_2.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=10000, n_jobs=None,
#              num_parallel_tree=None, random_state=0, ...)

# %%
predict_2test = model_2.predict(test)
predict_2test
# Out:
# array([127921.58, 162389.3 , 171169.42, ..., 139291.27, 114906.53,
#        217842.73], dtype=float32)

# %%
print(f"Mean absolute error in test dataset with xgboost: "+ str(abs(predict_2test.mean() - y_val.mean())))
# Out:
# Mean absolute error in test dataset with xgboost: SalePrice    2624.727312
# dtype: float64

# %%
df_xg_test = pd.DataFrame(predict_2test, columns = ['SalePrice'])
df_xg_test.index.name = 'Id'
df_xg_test
# Out:
#           SalePrice
# Id
# 0     127921.578125
# 1     162389.296875
# 2     171169.421875
# 3     185756.125000
# 4     194363.625000
# ...             ...
# 1454   84215.773438
# 1455   72501.757812
# 1456  139291.265625
# 1457  114906.531250
# 1458  217842.734375
#
# [1459 rows x 1 columns]

# %%
df_xg_test.to_csv('HousePricePredict.csv')
